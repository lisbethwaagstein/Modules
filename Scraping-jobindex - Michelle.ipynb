# %% [markdown]
# # Exam: Scraping job postings from Jobindex
#
# ....

# %%
import scraping_class
logfile = 'log_jobindex_scraping.txt'
connector = scraping_class.Connector(logfile)

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np

#define url and fetch the HTML using the requests module
url = 'https://www.jobindex.dk/jobsoegning?lang=da.html'
response = requests.get(url)  
html = response.text  
soup = BeautifulSoup(html,'lxml') # parse the raw html using BeautifoulSoup
#print(soup)

# %%
#find the max page number
max_page = soup.find('ul',{'class':'pagination'})
max_page2 = max_page.find_all('a', {'class':'page-link'})

def convert_value_type(value_node):
    if value_node.name == 'a':
        return value_node.text

page_list = []
for page in max_page2:
    page_list.append(convert_value_type(page))
#print(page_list[-1])

last_page = int(page_list[-1]) + 1 # we add one to use it in range in for-loop
print(last_page)
# Out:
# 649

# %%
#check exercise 6.1.4??
#Get all link pages from jobindex
jobindex_links = []
for i in range(1,last_page):
    url = f'https://www.jobindex.dk/jobsoegning?lang=da?page={i}.html'
    jobindex_links.append(url)   
#print(jobindex_links)

#Extract data from one page link first. We want the
url = 'https://www.jobindex.dk/jobsoegning?lang=da?page=1.html'
response = requests.get(url)  
html = response.text  
soup = BeautifulSoup(html,'lxml')

#one job result is given by class=jobsearch-result
joblistings = soup.find_all('div',{'class':'jobsearch-result'})
#print(joblistings)

# now find the a href hyperlinks of the individual jos postings. note: postings have many hyperlinks.
#first divide into postings in a list
postings = []
for posting_loc in html.split('<div class="jobsearch-result">')[1:]:
    posting = posting_loc.split('</div>')[0].lower()
    postings.append(posting)
#print(postings)

#now find all hyperlinks within a posting
links = []
for posting in postings:
    link_loc = tuple(posting.split('href="')[1:])    #this is made into a tuple to be able to call the second element.
    #link_loc2 = link_loc.split('"')[0]
    links.append(link_loc) 
print(len(links)) # there is 20 postings per page
#print(links)

#want to get the second element in all the "links" such as:
#print(links[1][1])
#print(links[2][1])
print(links[14][1])

all_links = []
for i in range(1,len(links)):
    #for link in links[i][1]:
    print(links[i][1].split('"')[0])
        
   # all_links.add(split('"')[0]) # this is where the link to the job posting is

#we have to replace "amp" in all links with ""
   
'''    
    for link in link_loc:
    second_link = link[.split('"')[0]
    links.append(second_link)
print(links)
#for link in links:
#    link_done = link.split('"')[0]
#    all_links.append(link_done)
#print(all_links) 
 #   link = link.split('"')[0]
'''
'''for link_loc in postings_join.split('href="')[1:]:
    link = link_loc.split('"')[0]
    links.add(link)
print(links)'''

'''for link_loc in 
    link = link_loc.split('"')[0]
    if '/categories/' in link:
        links.add(link)
print(len(links),list(links)[0]) # link is relative
links = ['https://www.trustpilot.com'+link for link in links]# add the domain to each link
links[:10]
'''
'''
url = 'https://www.jobindex.dk/jobsoegning?lang=da?page=1.html'
response, call_id = connector.get(url,'mapping_categories')
if response.ok:
    html = response.text
else:
    print('error')
'''                                      
'''
#Extract data from all the links
jobindex_data = []
for link in jobindex_links:
    response = requests.get(link)  
    html = response.text  
    soup = BeautifulSoup(html,'lxml') # parse the raw html using BeautifoulSoup
    
    #print(soup) '''   
https://candidate.hr-manager.net/ApplicationInit.aspx?cid=1627&ProjectId=143600&DepartmentId=18956&MediaId=4619
# Out:
# 20
# https://stormgroup.recruitee.com/o/salgskonsulent-til-sjov-social-hverdag" data-click="/c?t=h989946&amp;ctx=w&amp;u=20313204" rel="noopener" target="_blank"><b>salgskonsulent til sjov, social hverdag</b></a>
# <p>
# <a
# https://ikast-brande.emply.net/recruitment/vacancyad.aspx?publishingid=1fb545a3-1946-4afc-8484-9c336901cb5b
# https://ikast-brande.emply.net/recruitment/vacancyad.aspx?publishingid=5346be46-89e6-4202-aa7e-5f497d5ada6b
# https://www.jobindex.dk/jobannonce/366043/socialfaglig-medarbejder
# https://www.birn-partners.com/jobs/?hr=show-job%2f59547&amp;locale=da_dk
# https://www.jobindex.dk/jobannonce/366045/udekoerende-daekmontoer-til-alsidigt-arbejde
# https://www.innomate.com/innomatepublicpagesmedarb/jobnotice.aspx?companyid=zbc&amp;jobnoticeid=477
# https://www.innomate.com/innomatepublicpagesmedarb/jobnotice.aspx?companyid=zbc&amp;jobnoticeid=479
# https://candidate.hr-manager.net/applicationinit.aspx?cid=5001&amp;projectid=134384&amp;departmentid=7957&amp;mediaid=5&amp;skipadvertisement=false
# https://www.odense.dk/job?vacancyid=27322
# https://www.innomate.com/innomatepublicpagesmedarb/jobnotice.aspx?companyid=sde&amp;jobnoticeid=1176
# https://candidate.hr-manager.net/applicationinit.aspx?cid=1627&amp;projectid=143600&amp;departmentid=18956&amp;mediaid=4619
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-242-af90b78b6159> in <module>
#      42 for i in range(1,len(links)):
#      43     #for link in links[i][1]:
# ---> 44     print(links[i][1].split('"')[0])
#      45
#      46    # all_links.add(split('"')[0]) # this is where the link to the job posting is
#
# IndexError: tuple index out of range

# %%
#pip install slate3k
#pip install PyPDF2
#pip install textract
#pip install nltk
# Out:
# Collecting slate3kNote: you may need to restart the kernel to use updated packages.
#   Downloading slate3k-0.5.3-py2.py3-none-any.whl (7.9 kB)
# Collecting pdfminer3k
#   Downloading pdfminer3k-1.3.4-py3-none-any.whl (100 kB)
# Requirement already satisfied: ply in c:\users\miche\anaconda3\lib\site-packages (from pdfminer3k->slate3k) (3.11)
# Installing collected packages: pdfminer3k, slate3k
# Successfully installed pdfminer3k-1.3.4 slate3k-0.5.3

# %%
import requests
import slate3k as slate
#request the url
url = 'https://www.jobindex.dk/img/pdf/LRS210820SOC.pdf'
response = requests.get(url)

#save the pdf in the current folder
with open('pdf.pdf', 'wb') as f:
    f.write(response.content)

#open the pdf and get the text in doc
with open('pdf.pdf', 'rb') as fp:
    doc = slate.PDF(fp)
# Out:
# WARNING:root:Cannot locate objid=59

# %%
'''import PyPDF2 
import textract
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

#scraping a PDF file*
filename = 'pdf.pdf' 

#open allows you to read the file.
pdfFileObj = open(filename,'rb')

#The pdfReader variable is a readable object that will be parsed.
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

#Discerning the number of pages will allow us to parse through all the pages.
num_pages = pdfReader.numPages
count = 0
text = ""

#while loop reads each page and extracts the text
while count < num_pages:
    pageObj = pdfReader.getPage(count)
    count +=1
    text += pageObj.extractText()
    #pdf_text = str(text).replace('\n','')
print(text)'''
# Out:
# GolfBox A/S blev stiftet i 2003 og er siden blevet Skandinaviens største leverandør af administrationssoftware til golfklubber. GolfBox A/S™ software er 100% internetbaseret, hvilket bl.a. har medvirket til et stort teknologisk forspring i branchen globalt www.golfbox.netco@golfbox.dk. Sammen HenvendelseVi er i øjeblikket 19 engagerede medarbejdere hos GolfBox A/S.GolfBox A/S søger ambitiøs Programmør / Datamatiker+45 2173 4000 info@GolfBox.dk www.GolfBox.netGolfBox A/S Mere tid til golf...
# "\n#while loop reads each page and extracts the text\nwhile count < num_pages:\n    pageObj = pdfReader.getPage(count)\n    count +=1\n    text += pageObj.extractText()\n    #pdf_text = str(text).replace('\n','')\nprint(text)"

# %%
import re
import requests
#Define all the urls for the different geographical areas
url = 'https://www.jobindex.dk/jobsoegning'
response = requests.get(url)
html = response.text
soup = BeautifulSoup(html,'lxml')

#Areas are given in the html by div id=areas and class=area_label
areas_html = soup.find('div', {'id':'areas'})#('a', {'class':'area_label'})
areas_div = str(areas_html).split('href="/jobsoegning/')[1:]

#Find the links to each of the areas
areas = set()
for area in areas_div:
    link = area.split('"')[0]
    areas.add(link)

#Remove areas outside the borders of Denmark, i.e. Skåne, Færøerne, Grønland and Udlandet
print(areas)

#Scraping the geographical areas from jobindex
#the links to scrape are in the area_links list, so we want to loop over this one.
area_data = []
area_jobs = []

# first loop through areas
for area in areas:
    print('area: ' + area)
    url = f'https://www.jobindex.dk/jobsoegning/{area}' # make into max page at some point
    response = requests.get(url)  
    html = response.text  
    soup = BeautifulSoup(html,'lxml')   
    
    pagination = soup.find_all('a', {'class':'page-link'})
    if len(pagination) == 0:
        continue
    last_page = int(pagination[-1].text) 
    
    # loop through pages
    for page in range(1,last_page+1):
        if  page % 25 == 0:
            print('page: ',page,'/', last_page+1)
            
        url = f'https://www.jobindex.dk/jobsoegning/{area}?page={page}' # make into max page at some point
        response = requests.get(url)  
        html = response.text  
        soup = BeautifulSoup(html,'lxml') 
    
    #loop through job listings
        joblistings = soup.find_all('div',{'class':'jobsearch-result'})
    #area_data.append(joblistings) 
        for joblisting in joblistings:
            title = re.findall(r'(?<=<b>)(.*)(?=</b>)', str(joblisting))[0]
            if len(re.findall(r'(?<=<b>)(.*)(?=</b>)', str(joblisting)))>1:
                company = re.findall(r'(?<=<b>)(.*)(?=</b>)', str(joblisting))[1]
            else:
                company = ''
            geo_area = area
            job = [title, company, geo_area]
            area_jobs.append(job)
        
#Make into dataframe
import pandas as pd
df = pd.DataFrame(area_jobs)
df.columns = ["Job Title", "Company", "Geographical Area"]
df
#tjek dubletter på title!!
#SKÅNE (måske al udlandet) har "<strong>" før titel og ikke <b>... skal de fjernes!!!?

'''#find the max page for all the areas
page_links = [link for link in links if '?page=' in link] # check if the paging parameter is in the link
if len(page_links)==0: # no pages.
    return [category_link]
n_pages = max([int(link.split('page=')[-1]) for link in page_links]) # extract the page value and take the max
paging_links = [category_link] # define container and store the original result page
q = category_link+'?page=%d' # define the varying parameter string.
for num in range(2,n_pages+1): # build the links.
    paging_links.append(q%num)
return paging_links
max = paging_links
print(max)'''
# Out:
# area: region-nordjylland
# page:  25 / 48
# area: region-sjaelland
# page:  25 / 71
# page:  50 / 71
# area: faeroeerne
# area: groenland
# area: nordsjaelland
# page:  25 / 58
# page:  50 / 58
# area: danmark
# page:  25 / 626
# page:  50 / 626
# page:  75 / 626
# page:  100 / 626
# page:  125 / 626
# page:  150 / 626
# page:  175 / 626
# page:  200 / 626
# page:  225 / 626
# page:  250 / 626
# page:  275 / 626
# page:  300 / 626
# page:  325 / 626
# page:  350 / 626
# page:  375 / 626
# page:  400 / 626
# page:  425 / 626
# page:  450 / 626
# page:  475 / 626
# page:  500 / 626
# page:  525 / 626
# page:  550 / 626
# page:  575 / 626
# page:  600 / 626
# page:  625 / 626
# area: region-midtjylland
# page:  25 / 141
# page:  50 / 141
# page:  75 / 141
# page:  100 / 141
# page:  125 / 141
# area: storkoebenhavn
# page:  25 / 243
# page:  50 / 243
# page:  75 / 243
# page:  100 / 243
# page:  125 / 243
# page:  150 / 243
# page:  175 / 243
# page:  200 / 243
# page:  225 / 243
# area: udlandet
# area: sydjylland
# page:  25 / 74
# page:  50 / 74
# area: fyn
# page:  25 / 47
# area: skaane
# page:  25 / 26
# area: bornholm
# "#find the max page for all the areas\npage_links = [link for link in links if '?page=' in link] # check if the paging parameter is in the link\nif len(page_links)==0: # no pages.\n    return [category_link]\nn_pages = max([int(link.split('page=')[-1]) for link in page_links]) # extract the page value and take the max\npaging_links = [category_link] # define container and store the original result page\nq = category_link+'?page=%d' # define the varying parameter string.\nfor num in range(2,n_pages+1): # build the links.\n    paging_links.append(q%num)\nreturn paging_links\nmax = paging_links\nprint(max)"

# %%
import re
import requests
from bs4 import BeautifulSoup
import numpy as np

#Define all the urls for the different geographical areas
url = 'https://www.jobindex.dk/jobsoegning'
response = requests.get(url)
html = response.text
soup = BeautifulSoup(html,'lxml')

#Categories are given in the html by div id=areas and class=categories
cat_html = soup.find('div', {'id':'categories'})
cat_div = soup.find_all('a',{'class':'filter-section-header title collapsed'}) #the filter collapses

categories = []
sub_categories = []

for cat in cat_div:
    #first find the overall categories
    cat_name = re.findall(r'(?<=<span>)(.*)(?=<span class)', str(cat))[0]
    cat_name = cat_name.replace('\xad','')
    cat_links = re.findall("href=[\"\'](.*?)[\"\']", str(cat))
    cat_id = str(cat_links[0])
    cat_id = cat_id.replace('#','')
    category = [cat_name,cat_id]
    categories.append(category)
    #next find the sub-categories
    subcat_div = str(cat_html).split('href="/jobsoegning/')[1:]
for subcat in subcat_div:
    subcategory = subcat.split('"')[0]
    #cat_id = re.findall('(.*?)/', str(subcategory))
    #subcat_done = [subcategory,cat_id]
    sub_categories.append(subcategory)
#print(sub_categories)

#Scraping the different sub_categories of jobs (industries) from jobindex
category_data = []
category_jobs = []

# first loop through subcategories
for subcategory in sub_categories:
    print('subcategory: ' + subcategory)
    url = f'https://www.jobindex.dk/jobsoegning/{subcategory}'
    response = requests.get(url)  
    html = response.text  
    soup = BeautifulSoup(html,'lxml') 
    
    pagination = soup.find_all('a', {'class':'page-link'})
    if len(pagination) == 0: #if there is no job listings in a given subcategory
        continue
    last_page = int(pagination[-1].text) 
    
    # loop through pages
    for page in range(1,last_page+1):
        if  page % 25 == 0: #be able to follow how the proces
            print('page: ',page,'/', last_page+1)     
        url = f'https://www.jobindex.dk/jobsoegning/{subcategory}?page={page}' # make into max page at some point
        response = requests.get(url)  
        html = response.text  
        if '<strong>' in html: 
            html = html.replace('<strong>','<b>')\
                   .replace('</strong>','</b>')
        else:
            print('No <strong>')
        soup = BeautifulSoup(html,'lxml') 
    #loop through job listings
        joblistings = soup.find_all('div',{'class':'jobsearch-result'})
    #category_data.append(joblistings) 
        for joblisting in joblistings:
            title = re.findall(r'<b>(.*?)</b>', str(joblisting))[0]
            if len(re.findall(r'<b>(.*?)</b>', str(joblisting)))>1:
                company = re.findall(r'<b>(.*?)</b>', str(joblisting))[1]
                if 'amp;' in company:
                    company = company.replace('amp;','') 
            else: 
                company = ''
            cat_id = re.findall('(.*?)/', str(subcategory))
            subcat_id = subcategory
            job = [title, company, cat_id, subcat_id]
            category_jobs.append(job)
# Out:
# subcategory: it/database
# subcategory: it/itdrift
# subcategory: it/itkurser
# subcategory: it/itledelse
# subcategory: it/internet
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-177-31e23eeb7588> in <module>
#      64         else:
#      65             print('No <strong>')
# ---> 66         soup = BeautifulSoup(html,'lxml')
#      67     #loop through job listings
#      68         joblistings = soup.find_all('div',{'class':'jobsearch-result'})
#
# ~\anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     301             self.reset()
#     302             try:
# --> 303                 self._feed()
#     304                 break
#     305             except ParserRejectedMarkup:
#
# ~\anaconda3\lib\site-packages\bs4\__init__.py in _feed(self)
#     362         self.builder.reset()
#     363
# --> 364         self.builder.feed(self.markup)
#     365         # Close out any unfinished strings and close all the open tags.
#     366         self.endData()
#
# ~\anaconda3\lib\site-packages\bs4\builder\_lxml.py in feed(self, markup)
#     286         try:
#     287             self.parser = self.parser_for(encoding)
# --> 288             self.parser.feed(markup)
#     289             self.parser.close()
#     290         except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#
# src/lxml/parser.pxi in lxml.etree._FeedParser.feed()
#
# src/lxml/parser.pxi in lxml.etree._FeedParser.feed()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResult()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResult()
#
# src/lxml/etree.pyx in lxml.etree._ExceptionContext._raise_if_stored()
#
# src/lxml/saxparser.pxi in lxml.etree._handleSaxData()
#
# src/lxml/parsertarget.pxi in lxml.etree._PythonSaxParserTarget._handleSaxData()
#
# ~\anaconda3\lib\site-packages\bs4\builder\_lxml.py in data(self, content)
#     251         self.soup.endData(self.processing_instruction_class)
#     252
# --> 253     def data(self, content):
#     254         self.soup.handle_data(content)
#     255
#
# KeyboardInterrupt:

# %%
#Make into dataframe
import pandas as pd
df = pd.DataFrame(category_jobs)
df.columns = ["Job Title", "Company", "Category", "Subcategory"]
df[50:90]
# Out:
#                                             Job Title  \
# 50                        Director Data and Analytics
# 51      Digital Engineer, MuleSoft Integration Expert
# 52         Digital Engineer, Salesforce Service Cloud
# 53  Analytiker søges til at hunte statsstøttet cyb...
# 54                              Information Architect
# 55                                         Developers
# 56  Security Analyst in cutting edge Managed Detec...
# 57                                    Python-udvikler
# 58  Vi søger en udvikler til vores afdeling i Aalborg
# 59             SELVSTÆNDIG OG DYGTIG VIDENKOORDINATOR
# 60                                      Data Engineer
# 61  BI Engineer til Danmarks største online superm...
# 62  Systemingeniør til grøn omstilling af gassystemet
# 63                                     Data Engineers
# 64  Automation Engineer/Technician for Chemical En...
# 65    Outsourcing &amp; compliance consultant for BEC
# 66  GDPR senior consultants for new support team i...
# 67  Software Engineer - Back-end .Net software eng...
# 68                          DevOps- og Cloud-arkitekt
# 69                                    Pricing Actuary
# 70     DevOps specialist within continuous deployment
# 71                Senior IT-specialist til automation
# 72      IT Security Analyst til Netcompany Operations
# 73                 Back-End Developer - challenge us!
# 74                          Senior Software Developer
# 75  Teknisk spydspids til it-projekter hos CGI’s s...
# 76              Citrixspecialist til stor it-afdeling
# 77              Ny kollega til GIS- og geodataopgaver
# 78  Configuration Manager til tværgående rolle i s...
# 79  Systemadministrator til applikationsdrift af m...
# 80                              Data- og IT-konsulent
# 81     (Senior) Officer - Credit Risk Model Developer
# 82                       Information Security Manager
# 83              Cloud Engineer til Sentias Cloud Team
# 84  Kan du gøre en forskel inden for informationss...
# 85                  SCADA Component Security Engineer
# 86  Managing Architect til spændende Data Manageme...
# 87            Technical Solution Architect/Specialist
# 88                                Systemadministrator
# 89                              Cloud DevOps Engineer
#
#                                 Company Category  Subcategory
# 50                          PANDORA A/S     [it]  it/database
# 51                          PANDORA A/S     [it]  it/database
# 52                          PANDORA A/S     [it]  it/database
# 53     Forsvarets Efterretningstjeneste     [it]  it/database
# 54                Norlys Energy Trading     [it]  it/database
# 55                       Webshipper ApS     [it]  it/database
# 56              CSIS Security Group A/S     [it]  it/database
# 57      Brødrene A &amp; O Johansen A/S     [it]  it/database
# 58                      Conzentrate A/S     [it]  it/database
# 59         Horten Advokatpartnerselskab     [it]  it/database
# 60                           Alm. Brand     [it]  it/database
# 61                           nemlig.com     [it]  it/database
# 62                            Energinet     [it]  it/database
# 63                        LB Forsikring     [it]  it/database
# 64                             Lundbeck     [it]  it/database
# 65                                  BEC     [it]  it/database
# 66                                  BEC     [it]  it/database
# 67                          Danske Bank     [it]  it/database
# 68  Udviklings- og Forenklingsstyrelsen     [it]  it/database
# 69                  Tryg Forsikring A/S     [it]  it/database
# 70                                  BEC     [it]  it/database
# 71                                  DSV     [it]  it/database
# 72                           Netcompany     [it]  it/database
# 73                          Danske Bank     [it]  it/database
# 74      Hansen Technologies Denmark A/S     [it]  it/database
# 75                      CGI Danmark A/S     [it]  it/database
# 76                   Region Midtjylland     [it]  it/database
# 77                  Vordingborg Kommune     [it]  it/database
# 78                            Energinet     [it]  it/database
# 79  Udviklings- og Forenklingsstyrelsen     [it]  it/database
# 80                    Track Recruitment     [it]  it/database
# 81             European Investment Bank     [it]  it/database
# 82                           LEO Pharma     [it]  it/database
# 83                   Sentia Denmark A/S     [it]  it/database
# 84                        Toldstyrelsen     [it]  it/database
# 85                               Ørsted     [it]  it/database
# 86                           Netcompany     [it]  it/database
# 87                                  DSV     [it]  it/database
# 88                               Gensam     [it]  it/database
# 89                              KMD A/S     [it]  it/database

# %%
#find date for job posting
url = f'https://www.jobindex.dk/jobsoegning'
response = requests.get(url)  
html = response.text  
soup = BeautifulSoup(html,'lxml') 

joblistings = soup.find_all('div',{'class':'jobsearch-result'})
print(joblistings)

dates = []
for joblisting in joblistings:
    pub_date = re.findall(r'time\sdatetime="(.*)"', str(joblisting))
    dates.append(pub_date)    
print(dates)
# Out:
# [<div class="jobsearch-result"><div data-beacon-tid="h1002703"> <div class="PaidJob">
# <center style="margin-bottom: 15px;"><a data-click="/c?t=h1002703&amp;ctx=w&amp;u=15114019" href="http://ds-sundhed.dk/" rel="noopener" target="_blank"><img alt="Dansk Sundhedssikring A/S" src="/img/brand/dansk-sundhedssikring-spo-topp.jpg" style="border: 0px; margin: 0;"/></a></center><a data-click="/c?t=h1002703&amp;ctx=w&amp;u=20198355" href="https://ds-sundhed.career.emply.com/ad/vi-vaekster-derfor-soger-vi-sundhedsfaglige-radgivere/gdnqdi/da" rel="noopener" target="_blank"><b>Vi vækster - derfor søger vi sundhedsfaglige rådgivere</b></a>
# <p>
# <a data-click="/c?t=h1002703&amp;ctx=w&amp;u=15114019" href="http://ds-sundhed.dk/" rel="noopener" target="_blank"><b>Dansk Sundhedssikring A/S</b></a>, Herlev</p>
# <p><a data-click="/c?t=h1002703&amp;ctx=w&amp;u=20091516" href="https://jobindex.tv/video/57910682/dansk-sundhedssikring" rel="noopener" target="_blank"><img align="right" alt="Dansk Sundhedssikring A/S" src="/img/logo/_video-danskSunhedsSikring-200122.png" style="margin-left:10px;"/></a></p>
# <p><b> Brænder du for at gøre en forskel for vores kunder, så har du nu muligheden. Vi søger sygeplejekompetencer til at hjælpe med at rådgive vores mange forsikrede kunder. </b></p>
# I tæt samarbejde med andre erfarne sygeplejersker får du ansvaret for at rådgive vores kunder videre til den rigtige behandling. Du bliver det første bindeled i forbindelse med den telefoniske kontakt med vores kunder, som ønsker sundhedsfaglig rådgivning og vejledning i forbindelse med brugen af deres sundhedsforsikring.
# <p>Vigtigst af alt formår du at give den samme gode service til alle kunder uanset skadens omfang eller sygdommens alvor – og det er op til dig at forene de bedste elementer mellem det offentlige og private.</p><center><a data-click="/c?t=h1002703&amp;ctx=w&amp;u=20049170" href="https://www.jobindex.dk/virksomhed/36309/dansk-sundhedssikring-a-s" rel="noopener" target="_blank"><img alt="Dansk Sundhedssikring A/S" src="/img/brand/dansk-sundhedssikring-spo-bund.jpg" style="border: 0px; margin-top: 5px;"/></a></center>
# <div class="jix_toolbar jix_appetizer_toolbar" id="jix_toolbar_h1002703">
# <ul class="toolbar-line toolbar-line-primary">
# <li class="jobad-element-myjob" data-state="unsaved">
# <a data-action="add-dialog" href="/bruger/dine-job/h1002703/gem" rel="nofollow">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-unsaved" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#         Gem job
# </a></li>
# <li class="jobad-element-myjob-interest" data-state="notallowed">
# <a data-action="handlecontact" href="/bruger/dine-job/h1002703/skift_kontakt" rel="nofollow">
# <span class=""><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-interest-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Vis interesse</span>
# </a></li>
# <li class="jobad-element-share"><a data-share-popup-url="/share/popup/h1002703" data-share-tid="h1002703" data-share-title="Vi vækster - derfor søger vi sundhedsfaglige rådgivere" data-share-url="https://www.jobindex.dk/vis-job/h1002703" href="/send-link?link=https%253A%252F%252Fwww.jobindex.dk%252Fvis-job%252Fh1002703&amp;s=5ce32b502adc80e306778de147c5bdeff17c7720">Del</a></li>
# <li class="toolbar-pubdate"><span class="d-none d-md-inline">Indrykket </span><time datetime="2020-08-24">24. august</time></li>
# </ul>
# <ul class="toolbar-line toolbar-line-secondary has-rating">
# <li class="toolbar-companyprofile">
# <a href="/virksomhed/36309/dansk-sundhedssikring-a-s" onclick="ga('send', 'event', 'jobannonce', 'click', 'om-virksomheden', {transport: 'beacon'})">Om virksomheden</a>
# <span class="ratings">
# <a class="rating-score" href="/virksomhed/36309/dansk-sundhedssikring-a-s#show_rating" onclick="ga('send', 'event', 'jobannonce', 'click', 'evalueringsstjerner', {transport: 'beacon'})">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# <span class="sr-only">5 af 5 stjerner</span>
# </a>
# <a class="num-ratings" href="/virksomhed/36309/dansk-sundhedssikring-a-s#show_rating" onclick="ga('send', 'event', 'jobannonce', 'click', 'evalueringsstjerner', {transport: 'beacon'})">14</a>
# </span>
# </li>
# <li class="jobad-element-quickapply">
# <a class="btn btn-sm btn-primary" href="https://www.jobindex.dk/c?t=e1270946&amp;ctx=w&amp;u=20198356&amp;f=jobdk" onclick='ga("send", "event", "jobannonce", "click", "quick-apply", {transport: "beacon"})'>QuickApply</a>
# </li>
# </ul>
# </div>
# <div style="clear:both;"></div>
# </div>
# </div></div>, <div class="jobsearch-result"><div data-beacon-tid="h1002686"> <div class="PaidJob">
# <a data-click="/c?t=h1002686&amp;ctx=w&amp;u=13590487" href="http://www.accountor.dk/" rel="noopener" target="_blank"><img align="right" alt="Accountor Denmark A/S" src="/img/logo/danmarksygeforsikring.gif" style="border: 0px; margin: 0 0 5px 20px;"/></a><a data-click="/c?t=h1002686&amp;ctx=w&amp;u=20348521" href="https://accountor.emply.net/recruitment/vacancyAd.aspx?publishingId=5b406716-d516-4045-b26f-b357dd0c1013" rel="noopener" target="_blank"><b>Alsidig regnskabsansvarlig med hands-on på opgaverne søges til Sygeforsikringen ”danmark”</b></a>
# <p>
# <a data-click="/c?t=h1002686&amp;ctx=w&amp;u=13590487" href="http://www.accountor.dk/" rel="noopener" target="_blank"><b>Accountor Denmark A/S</b></a> søger for Sygeforsikringen "danmark" i København</p>
# <p>Trives du i en stilling, hvor du har det faglige ansvar for bogholderifunktionen med 4 medarbejdere og selv deltager i de daglige opgaver? Byder du ind med optimerings- og udviklingstiltag på processer og arbejdsgange og motiveres du af de mange ad hoc-opgaver og projekter, så er dette måske dit næste job. </p>
# <p> Med reference til økonomichefen vil du få en selvstændig rolle med en bred vifte af arbejdsopgaver, lige fra de daglige bogholderiopgaver til udviklingsopgaver på processer og arbejdsgange samt deltagelse i de mange ad hoc-opgaver og projekter. </p>
# <p>Med fokus på Sygeforsikringen ”danmark” vil dine vigtigste arbejdsopgaver være som følgende: </p>
# <ul>
# <li> Ansvarlig for den daglige bogføring med hands-on. </li>
# <li> Ansvarlig for de daglige og månedlige afstemninger, der er tilknyttet bogholderifunktionen. </li>
# </ul>
# <div class="jix_toolbar jix_appetizer_toolbar" id="jix_toolbar_h1002686">
# <ul class="toolbar-line toolbar-line-primary">
# <li class="jobad-element-myjob" data-state="unsaved">
# <a data-action="add-dialog" href="/bruger/dine-job/h1002686/gem" rel="nofollow">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-unsaved" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#         Gem job
# </a></li>
# <li class="jobad-element-myjob-interest" data-state="notallowed">
# <a data-action="handlecontact" href="/bruger/dine-job/h1002686/skift_kontakt" rel="nofollow">
# <span class=""><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-interest-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Vis interesse</span>
# </a></li>
# <li class="jobad-element-share"><a data-share-popup-url="/share/popup/h1002686" data-share-tid="h1002686" data-share-title="Alsidig regnskabsansvarlig med hands-on på opgaverne søges til Sygeforsikringen ”danmark”" data-share-url="https://www.jobindex.dk/vis-job/h1002686" href="/send-link?link=https%253A%252F%252Fwww.jobindex.dk%252Fvis-job%252Fh1002686&amp;s=d2346883f0f2ac9e6687e9c021ad3bf771844146">Del</a></li>
# <li class="toolbar-pubdate"><span class="d-none d-md-inline">Indrykket </span><time datetime="2020-08-24">24. august</time></li>
# </ul>
# <ul class="toolbar-line toolbar-line-secondary has-rating">
# <li class="toolbar-companyprofile">
# <a href="/virksomhed/457/sygeforsikringen-danmark" onclick="ga('send', 'event', 'jobannonce', 'click', 'om-virksomheden', {transport: 'beacon'})">Om virksomheden</a>
# <span class="ratings">
# <a class="rating-score" href="/virksomhed/457/sygeforsikringen-danmark#show_rating" onclick="ga('send', 'event', 'jobannonce', 'click', 'evalueringsstjerner', {transport: 'beacon'})">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# <span class="sr-only">4 af 5 stjerner</span>
# </a>
# <a class="num-ratings" href="/virksomhed/457/sygeforsikringen-danmark#show_rating" onclick="ga('send', 'event', 'jobannonce', 'click', 'evalueringsstjerner', {transport: 'beacon'})">4</a>
# </span>
# </li>
# <li class="jobad-element-quickapply">
# <a class="btn btn-sm btn-primary" href="https://www.jobindex.dk/c?t=e1270849&amp;ctx=w&amp;u=20348522&amp;f=jobdk" onclick='ga("send", "event", "jobannonce", "click", "quick-apply", {transport: "beacon"})'>QuickApply</a>
# </li>
# </ul>
# </div>
# <div style="clear:both;"></div>
# </div>
# </div></div>, <div class="jobsearch-result"><div data-beacon-tid="h1002684"> <div class="PaidJob">
# <a data-click="/c?t=h1002684&amp;ctx=w&amp;u=18991287" href="http://www.husetvedskoven.dk/" rel="noopener" target="_blank"><img align="right" alt="S/I Huset ved Skoven" src="/img/logo/Husetvskoven_logo.png" style="border: 0px; margin: 0 0 5px 20px;"/></a><a data-click="/c?t=h1002684&amp;ctx=w&amp;u=20348518" href="https://www.jobindex.dk/jobannonce/366156/vil-du-vaere-med-til-at-tage-ansvar-for-en-organisation-i-udvikling" rel="noopener" target="_blank"><b>Vil du være med til at tage ansvar for en organisation i udvikling?</b></a>
# <p>
# <a data-click="/c?t=h1002684&amp;ctx=w&amp;u=18991287" href="http://www.husetvedskoven.dk/" rel="noopener" target="_blank"><b>S/I Huset ved Skoven</b></a></p>
# <p>Har du ben i næsen og benene plantet solidt på jorden? Kan du sætte grænser og være omsorgsfuld på samme tid?</p>
# <p> Har du erfaring med og brænder for at arbejde med miljøterapi – er det måske dig vi søger. Vil du være med til give vores borgere en god dag, og samtidig være med til at udvikle og styrke deres kompetencer i et trygt miljø?</p>
# <p>Vi søger nye kollegaer, som er uddannet pædagog eller sundhedsfagligt til 30 og 37 timers stillinger, samtidig søger vi vikarer i flere af vores huse. De ledige stillinger vil p.t. være i Kalundborg, Eskebjerg, Høng og Dalmose.</p>
# <p> De fysiske rammer rummer både hus og have, og på sigt også høns og urtehave, og du skal være indstillet på at være med til at holde de udvendige rammer, også gerne fantasi og ideer.</p>
# <div class="jix_toolbar jix_appetizer_toolbar" id="jix_toolbar_h1002684">
# <ul class="toolbar-line toolbar-line-primary">
# <li class="jobad-element-myjob" data-state="unsaved">
# <a data-action="add-dialog" href="/bruger/dine-job/h1002684/gem" rel="nofollow">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-unsaved" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#         Gem job
# </a></li>
# <li class="jobad-element-myjob-interest" data-state="notallowed">
# <a data-action="handlecontact" href="/bruger/dine-job/h1002684/skift_kontakt" rel="nofollow">
# <span class=""><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-interest-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Vis interesse</span>
# </a></li>
# <li class="jobad-element-share"><a data-share-popup-url="/share/popup/h1002684" data-share-tid="h1002684" data-share-title="Vil du være med til at tage ansvar for en organisation i udvikling?" data-share-url="https://www.jobindex.dk/vis-job/h1002684" href="/send-link?link=https%253A%252F%252Fwww.jobindex.dk%252Fvis-job%252Fh1002684&amp;s=e77ca4316352b0996f2bdae7e5290e6df9d1146c">Del</a></li>
# <li class="toolbar-pubdate"><span class="d-none d-md-inline">Indrykket </span><time datetime="2020-08-24">24. august</time></li>
# </ul>
# <ul class="toolbar-line toolbar-line-secondary">
# <li class="toolbar-companyprofile">
# <a href="/virksomhed/47968/s-i-huset-ved-skoven" onclick="ga('send', 'event', 'jobannonce', 'click', 'om-virksomheden', {transport: 'beacon'})">Om virksomheden</a>
# </li>
# <li class="jobad-element-quickapply">
# <a class="btn btn-sm btn-primary" href="https://www.jobindex.dk/ansoegninger/opret/1308077" onclick='ga("send", "event", "jobannonce", "click", "quick-apply", {transport: "beacon"})'>QuickApply</a>
# </li>
# </ul>
# </div>
# <div style="clear:both;"></div>
# </div>
# </div></div>, <div class="jobsearch-result"><div data-beacon-tid="h1002681"> <div class="PaidJob">
# <a data-click="/c?t=h1002681&amp;ctx=w&amp;u=19345105" href="http://www.odenseboligselskab.dk/" rel="noopener" target="_blank"><img align="right" alt="Odense Boligselskab" src="/img/logo/OBO170918_logo.gif" style="border: 0px; margin: 0 0 5px 20px;"/></a><a data-click="/c?t=h1002681&amp;ctx=w&amp;u=20348513" href="https://www.jobindex.dk/jobannonce/366155/vi-soeger-ejendomsservicetekniker-varmemester" rel="noopener" target="_blank"><b>VI SØGER EJENDOMSSERVICETEKNIKER/VARMEMESTER</b></a>
# <p>
# <a data-click="/c?t=h1002681&amp;ctx=w&amp;u=19345105" href="http://www.odenseboligselskab.dk/" rel="noopener" target="_blank"><b>Odense Boligselskab</b></a></p>
# <p> Vi har mange bolde i luften og har derfor behov for 2 ekstra mand til vores tekniske serviceteam i Odense Boligselskab. </p>
# <p><b> Ejendomsservicetekniker</b> til vores afdelinger i Odense SØ. </p>
# <ul>
# <li>Vedligeholdelsesopgaver i lejligheder samt indvendige og udvendige fri-/fællesarealer</li>
# <li>Flyttesyn af lejligheder, både udflytninger og indflytninger</li>
# <li>Rekvirering af håndværkere via computer samt kontrol af håndværkere og andre leverandører</li>
# <li>Beboerservice</li>
# </ul>
# <p><b>Varmemester til nybygget seniorbofællesskab</b> med et stort socialt hjerte.<br/>
# Dette er en helt særlig stilling. Ikke nok med du som ovenstående skal passe på bygningen, du skal også understøtte beboerfællesskabet. Denne stilling kræver derfor, at du er ekstra god til at tale med beboerne og hjælpe dem med både deres store og små problemer. </p>
# <div class="jix_toolbar jix_appetizer_toolbar" id="jix_toolbar_h1002681">
# <ul class="toolbar-line toolbar-line-primary">
# <li class="jobad-element-myjob" data-state="unsaved">
# <a data-action="add-dialog" href="/bruger/dine-job/h1002681/gem" rel="nofollow">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-unsaved" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#         Gem job
# </a></li>
# <li class="jobad-element-myjob-interest" data-state="notallowed">
# <a data-action="handlecontact" href="/bruger/dine-job/h1002681/skift_kontakt" rel="nofollow">
# <span class=""><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-interest-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Vis interesse</span>
# </a></li>
# <li class="jobad-element-share"><a data-share-popup-url="/share/popup/h1002681" data-share-tid="h1002681" data-share-title="VI SØGER EJENDOMSSERVICETEKNIKER/VARMEMESTER" data-share-url="https://www.jobindex.dk/vis-job/h1002681" href="/send-link?link=https%253A%252F%252Fwww.jobindex.dk%252Fvis-job%252Fh1002681&amp;s=f964eb160a598dc85b1e71f98bab54f0d44d41c6">Del</a></li>
# <li class="toolbar-pubdate"><span class="d-none d-md-inline">Indrykket </span><time datetime="2020-08-24">24. august</time></li>
# </ul>
# <ul class="toolbar-line toolbar-line-secondary">
# <li class="toolbar-companyprofile">
# <a href="/virksomhed/52284/odense-boligselskab" onclick="ga('send', 'event', 'jobannonce', 'click', 'om-virksomheden', {transport: 'beacon'})">Om virksomheden</a>
# </li>
# <li class="jobad-element-quickapply">
# <a class="btn btn-sm btn-primary" href="https://www.jobindex.dk/ansoegninger/opret/1308074" onclick='ga("send", "event", "jobannonce", "click", "quick-apply", {transport: "beacon"})'>QuickApply</a>
# </li>
# </ul>
# </div>
# <div style="clear:both;"></div>
# </div>
# </div></div>, <div class="jobsearch-result"><div data-beacon-tid="h1002679"> <div class="PaidJob">
# <a data-click="/c?t=h1002679&amp;ctx=w&amp;u=18902834" href="http://www.unic-automatik.dk/" rel="noopener" target="_blank"><img align="right" alt="Unic Automatik ApS" src="/img/logo/Unic_automatic_logo.gif" style="border: 0px; margin: 0 0 5px 20px;"/></a><a data-click="/c?t=h1002679&amp;ctx=w&amp;u=20348509" href="https://www.jobindex.dk/jobannonce/366153/projektleder-sjaelland" rel="noopener" target="_blank"><b>Projektleder – Sjælland</b></a>
# <p>
# <a data-click="/c?t=h1002679&amp;ctx=w&amp;u=18902834" href="http://www.unic-automatik.dk/" rel="noopener" target="_blank"><b>Unic Automatik ApS</b></a>, Hedehusene</p>
# <p><b> Unic Automatik ApS beskæftiger sig med intelligent bygningsautomatik og er et certificeret Tridium, BA Systems- og Regin Systemhus. </b></p>
# <p><b> Vi søger en CTS-projektleder til at tage ansvar for gennemførelse af BMS-/CTS-projekter, fra opstart til overdragelse. Ligeledes har vi en forventning om at du tager ejerskab i at vi sammen kan udvikle CTS-afdelingen på Sjælland. </b></p>
# <p>Om jobbet </p>
# <ul>
# <li> Du vil få din daglige gang i vores afdeling i Hedehusene på Sjælland og ude på byggepladsen. </li>
# <li> Din opgave bliver at drive projekterne fra opstart til overdragelse til kunderne. </li>
# <li> Projektering, tegning og design samt dokumentation af alle typer opgaver inden for CTS-/BMS-løsninger.</li>
# </ul>
# <p>Vi tilbyder et alsidigt og udfordrende job med gode udviklingsmuligheder. Du vil løbende få opdateret din tekniske viden inden for området. </p>
# <div class="jix_toolbar jix_appetizer_toolbar" id="jix_toolbar_h1002679">
# <ul class="toolbar-line toolbar-line-primary">
# <li class="jobad-element-myjob" data-state="unsaved">
# <a data-action="add-dialog" href="/bruger/dine-job/h1002679/gem" rel="nofollow">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-unsaved" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#         Gem job
# </a></li>
# <li class="jobad-element-myjob-interest" data-state="notallowed">
# <a data-action="handlecontact" href="/bruger/dine-job/h1002679/skift_kontakt" rel="nofollow">
# <span class=""><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-interest-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Vis interesse</span>
# </a></li>
# <li class="jobad-element-share"><a data-share-popup-url="/share/popup/h1002679" data-share-tid="h1002679" data-share-title="Projektleder – Sjælland" data-share-url="https://www.jobindex.dk/vis-job/h1002679" href="/send-link?link=https%253A%252F%252Fwww.jobindex.dk%252Fvis-job%252Fh1002679&amp;s=79a1bbb4b309225dfd74c0c471407ce64c0ac5f2">Del</a></li>
# <li class="toolbar-pubdate"><span class="d-none d-md-inline">Indrykket </span><time datetime="2020-08-24">24. august</time></li>
# </ul>
# <ul class="toolbar-line toolbar-line-secondary">
# <li class="toolbar-companyprofile">
# <a href="/virksomhed/46527/unic-automatik-aps" onclick="ga('send', 'event', 'jobannonce', 'click', 'om-virksomheden', {transport: 'beacon'})">Om virksomheden</a>
# </li>
# <li class="jobad-element-quickapply">
# <a class="btn btn-sm btn-primary" href="https://www.jobindex.dk/ansoegninger/opret/1308071" onclick='ga("send", "event", "jobannonce", "click", "quick-apply", {transport: "beacon"})'>QuickApply</a>
# </li>
# </ul>
# </div>
# <div style="clear:both;"></div>
# </div>
# </div></div>, <div class="jobsearch-result"><div data-beacon-tid="h1002674"> <div class="PaidJob">
# <a data-click="/c?t=h1002674&amp;ctx=w&amp;u=15166059" href="http://www.frederikshavn.dk/" rel="noopener" target="_blank"><img align="right" alt="Frederikshavn Kommune" src="/img/logo/fhk_logo_mer20100713.gif" style="border: 0px; margin: 0 0 5px 20px;"/></a><a data-click="/c?t=h1002674&amp;ctx=w&amp;u=20348497" href="https://frederikshavn.emply.net/recruitment/vacancyAd.aspx?publishingId=5acbab2e-f27b-4374-85ea-43016c5d6d95" rel="noopener" target="_blank"><b>Er du klar til at bruge dine SSA-kompetencer i Hjemmeplejen?</b></a>
# <p>
# <a data-click="/c?t=h1002674&amp;ctx=w&amp;u=15166059" href="http://www.frederikshavn.dk/" rel="noopener" target="_blank"><b>Frederikshavn Kommune</b></a></p>
# <p>Område Øst søger tre faglig dygtige social– og sundhedsassistenter til dagvagt, som i tæt samarbejde med områdets sygeplejersker kan løse de komplekse og delegerede sygeplejeopgaver i hjemmeplejen.</p>
# <p> Du vil skulle tiltræde pr. 1. november 2020 eller snarest muligt. Stillingen er på 35 timer med arbejde hver 3. weekend. Der vil kunne forekomme enkelte aftenvagter. </p>
# <p> Vi kunne tænke os at du:</p>
# <ul>
# <li> Er en god rollemodel, er udviklings- og omstillingsparat, samt har stor grad af fleksibilitet, således at vi kan levere den bedste service til vores borgere inden for de givne rammer. </li>
# <li> Kan bidrage til et godt arbejdsmiljø blandt dine kollegaer — selv i en travl hverdag. </li>
# <li> Kan bidrage til et godt tværfagligt samarbejde. </li>
# </ul>
# <div class="jix_toolbar jix_appetizer_toolbar" id="jix_toolbar_h1002674">
# <ul class="toolbar-line toolbar-line-primary">
# <li class="jobad-element-myjob" data-state="unsaved">
# <a data-action="add-dialog" href="/bruger/dine-job/h1002674/gem" rel="nofollow">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-unsaved" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#         Gem job
# </a></li>
# <li class="jobad-element-myjob-interest" data-state="notallowed">
# <a data-action="handlecontact" href="/bruger/dine-job/h1002674/skift_kontakt" rel="nofollow">
# <span class=""><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-interest-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Vis interesse</span>
# </a></li>
# <li class="jobad-element-share"><a data-share-popup-url="/share/popup/h1002674" data-share-tid="h1002674" data-share-title="Er du klar til at bruge dine SSA-kompetencer i Hjemmeplejen?" data-share-url="https://www.jobindex.dk/vis-job/h1002674" href="/send-link?link=https%253A%252F%252Fwww.jobindex.dk%252Fvis-job%252Fh1002674&amp;s=2f5c3b85d4f7d082ede91de6ef9fb0b119a6fdc8">Del</a></li>
# <li class="toolbar-pubdate"><span class="d-none d-md-inline">Indrykket </span><time datetime="2020-08-24">24. august</time></li>
# </ul>
# <ul class="toolbar-line toolbar-line-secondary">
# <li class="toolbar-companyprofile">
# <a href="/virksomhed/28218/frederikshavn-kommune" onclick="ga('send', 'event', 'jobannonce', 'click', 'om-virksomheden', {transport: 'beacon'})">Om virksomheden</a>
# </li>
# <li class="jobad-element-quickapply">
# <a class="btn btn-sm btn-primary" href="https://www.jobindex.dk/c?t=e1270841&amp;ctx=w&amp;u=20348498&amp;f=jobdk" onclick='ga("send", "event", "jobannonce", "click", "quick-apply", {transport: "beacon"})'>QuickApply</a>
# </li>
# </ul>
# </div>
# <div style="clear:both;"></div>
# </div>
# </div></div>, <div class="jobsearch-result"><div data-beacon-tid="h1002661"> <div class="PaidJob">
# <center style="margin-bottom: 15px;"><a data-click="/c?t=h1002661&amp;ctx=w&amp;u=15135593" href="http://www.sekologistics.com/" rel="noopener" target="_blank"><img alt="SEKO Logistics" src="/img/brand/seko-top-2017.jpg" style="border: 0px; margin: 0;"/></a></center><a data-click="/c?t=h1002661&amp;ctx=w&amp;u=20348530" href="https://www.jobindex.dk/jobannonce/366148/lagermedarbejder-til-pluk-og-pak" rel="noopener" target="_blank"><b>Lagermedarbejder til pluk og pak</b></a>
# <p>
# <a data-click="/c?t=h1002661&amp;ctx=w&amp;u=15135593" href="http://www.sekologistics.com/" rel="noopener" target="_blank"><b>SEKO Logistics</b></a>, Brøndby</p>
# <p> Vi søger en medarbejder til vores lager som primært vil beskæftige sig med pluk og pak af ordrer for vores kunder. Vi værdsætter gode holdspillere som hjælpes til at nå deadlines, sikre en høj kvalitet og samtidig er glade for deres hverdag i SEKO Logistics hvor tonen er uformel og der er frihed under ansvar. </p>
# <p>Arbejdsopgaver: </p>
# <ul>
# <li> Pakning og plukning </li>
# <li> Oprydning/sortering </li>
# <li> Kontrol </li>
# <li> Forefaldende lagerarbejde </li>
# </ul><center><img alt="SEKO Logistics" src="/img/brand/seko-bund-2017.jpg" style="border: 0px; margin-top: 5px;"/></center>
# <div class="jix_toolbar jix_appetizer_toolbar" id="jix_toolbar_h1002661">
# <ul class="toolbar-line toolbar-line-primary">
# <li class="jobad-element-myjob" data-state="unsaved">
# <a data-action="add-dialog" href="/bruger/dine-job/h1002661/gem" rel="nofollow">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-unsaved" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#         Gem job
# </a></li>
# <li class="jobad-element-myjob-interest" data-state="notallowed">
# <a data-action="handlecontact" href="/bruger/dine-job/h1002661/skift_kontakt" rel="nofollow">
# <span class=""><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-interest-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Vis interesse</span>
# </a></li>
# <li class="jobad-element-share"><a data-share-popup-url="/share/popup/h1002661" data-share-tid="h1002661" data-share-title="Lagermedarbejder til pluk og pak" data-share-url="https://www.jobindex.dk/vis-job/h1002661" href="/send-link?link=https%253A%252F%252Fwww.jobindex.dk%252Fvis-job%252Fh1002661&amp;s=63cc31d3cef211f5e944766a4154ee777a2d5dfc">Del</a></li>
# <li class="toolbar-pubdate"><span class="d-none d-md-inline">Indrykket </span><time datetime="2020-08-24">24. august</time></li>
# </ul>
# <ul class="toolbar-line toolbar-line-secondary">
# <li class="toolbar-companyprofile">
# <a href="/virksomhed/29578/seko-logistics" onclick="ga('send', 'event', 'jobannonce', 'click', 'om-virksomheden', {transport: 'beacon'})">Om virksomheden</a>
# </li>
# <li class="jobad-element-quickapply">
# <a class="btn btn-sm btn-primary" href="https://www.jobindex.dk/ansoegninger/opret/1308048" onclick='ga("send", "event", "jobannonce", "click", "quick-apply", {transport: "beacon"})'>QuickApply</a>
# </li>
# </ul>
# </div>
# <div style="clear:both;"></div>
# </div>
# </div></div>, <div class="jobsearch-result"><div data-beacon-tid="h1002659"> <div class="PaidJob">
# <a data-click="/c?t=h1002659&amp;ctx=w&amp;u=20348487" href="http://www.arcedi.com/" rel="noopener" target="_blank"><img align="right" alt="Arcedi Biotech ApS" src="/img/logo/ARCEDI240820_logo.png" style="border: 0px; margin: 0 0 5px 20px;"/></a><a data-click="/c?t=h1002659&amp;ctx=w&amp;u=20348488" href="https://www.jobindex.dk/jobannonce/366145/forskningsbioanalytiker" rel="noopener" target="_blank"><b>Forskningsbioanalytiker</b></a>
# <p>
# <a data-click="/c?t=h1002659&amp;ctx=w&amp;u=20348487" href="http://www.arcedi.com/" rel="noopener" target="_blank"><b>Arcedi Biotech ApS</b></a>, Aarhus</p>
# <p> Vi søger en positiv, engageret, selvstændig &amp; initiativrig bioanalytiker til en ledig stilling fra 1. november 2020. </p>
# <p> Vi er en privat bioteknologisk virksomhed, der i et tæt samarbejde med Aarhus Universitets Hospital har udviklet en metode til celle-baseret noninvasive fosterdiagnostisk test (cbNIPT). Vi holder til i forskningslaboratorierne for kvindesygdomme og fødsler, AUH, hvor vi arbejder med både kliniske valideringsstudier af vores cbNIPT-test samt en række forskellige forskningsprojekter i samarbejde med både danske samt internationale forskningsgrupper. </p>
# <p> Vi kan tilbyde et spændende job med mange forskellige opgaver på en dynamisk arbejdsplads i rivende udvikling. Din arbejdsfunktion vil omfatte registrering og processering af indkomne blodprøver samt laboratorieanalyser som MACS, FACS, DNA-oprensning og forskellige typer PCR til genetiske analyser. </p>
# <div class="jix_toolbar jix_appetizer_toolbar" id="jix_toolbar_h1002659">
# <ul class="toolbar-line toolbar-line-primary">
# <li class="jobad-element-myjob" data-state="unsaved">
# <a data-action="add-dialog" href="/bruger/dine-job/h1002659/gem" rel="nofollow">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-unsaved" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#         Gem job
# </a></li>
# <li class="jobad-element-myjob-interest" data-state="notallowed">
# <a data-action="handlecontact" href="/bruger/dine-job/h1002659/skift_kontakt" rel="nofollow">
# <span class=""><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-interest-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Vis interesse</span>
# </a></li>
# <li class="jobad-element-share"><a data-share-popup-url="/share/popup/h1002659" data-share-tid="h1002659" data-share-title="Forskningsbioanalytiker" data-share-url="https://www.jobindex.dk/vis-job/h1002659" href="/send-link?link=https%253A%252F%252Fwww.jobindex.dk%252Fvis-job%252Fh1002659&amp;s=b55375ee518b9b785372f6f0bb30c6c978e1148c">Del</a></li>
# <li class="toolbar-pubdate"><span class="d-none d-md-inline">Indrykket </span><time datetime="2020-08-24">24. august</time></li>
# </ul>
# <ul class="toolbar-line toolbar-line-secondary">
# <li class="toolbar-companyprofile">
# <a href="/virksomhed/56909/arcedi-biotech-aps" onclick="ga('send', 'event', 'jobannonce', 'click', 'om-virksomheden', {transport: 'beacon'})">Om virksomheden</a>
# </li>
# <li class="jobad-element-quickapply">
# <a class="btn btn-sm btn-primary" href="https://www.jobindex.dk/ansoegninger/opret/1308045" onclick='ga("send", "event", "jobannonce", "click", "quick-apply", {transport: "beacon"})'>QuickApply</a>
# </li>
# </ul>
# </div>
# <div style="clear:both;"></div>
# </div>
# </div></div>, <div class="jobsearch-result"><div data-beacon-tid="h1002649"> <div class="PaidJob">
# <a data-click="/c?t=h1002649&amp;ctx=w&amp;u=15182968" href="http://www.copenhagenfertilitycenter.com/" rel="noopener" target="_blank"><img align="right" alt="Copenhagen Fertility Center" src="/img/logo/copenhagenfertility.jpg" style="border: 0px; margin: 0 0 5px 20px;"/></a><a data-click="/c?t=h1002649&amp;ctx=w&amp;u=20348475" href="https://www.jobindex.dk/jobannonce/366136/laegesekretaer" rel="noopener" target="_blank"><b>Lægesekretær</b></a>
# <p>
# <a data-click="/c?t=h1002649&amp;ctx=w&amp;u=15182968" href="http://www.copenhagenfertilitycenter.com/" rel="noopener" target="_blank"><b>Copenhagen Fertility Center</b></a></p>
# <p> Brænder du for tværfaglighed, stor faglig viden om patienternes behandling, og vil du være en vigtig del af patientforløbet? Så er det dig, vi mangler! </p>
# <p> Dine arbejdsopgaver: </p>
# <ul>
# <li>Du er klinikkens knudepunkt imellem patienter, personale og øvrige afdelinger. </li>
# <li>Du er kontaktfladen til de patienter, der henvender sig i klinikken. </li>
# <li>Du har kommunikationen med patienterne og kan besvare deres spørgsmål omkring fertilitetsbehandling. </li>
# </ul>
# <p> Vi er en gruppe på 4 faste sekretærer og 6 medicinstuderende. Vi supplerer hinanden godt med vores forskellige personligheder og kompetencer. Vi udviser gensidig respekt og har masser af godt humør. Sekretærerne deltager i tværfaglige møder, konferencer og kurser. </p>
# <div class="jix_toolbar jix_appetizer_toolbar" id="jix_toolbar_h1002649">
# <ul class="toolbar-line toolbar-line-primary">
# <li class="jobad-element-myjob" data-state="unsaved">
# <a data-action="add-dialog" href="/bruger/dine-job/h1002649/gem" rel="nofollow">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-unsaved" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#         Gem job
# </a></li>
# <li class="jobad-element-myjob-interest" data-state="notallowed">
# <a data-action="handlecontact" href="/bruger/dine-job/h1002649/skift_kontakt" rel="nofollow">
# <span class=""><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-interest-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Vis interesse</span>
# </a></li>
# <li class="jobad-element-share"><a data-share-popup-url="/share/popup/h1002649" data-share-tid="h1002649" data-share-title="Lægesekretær" data-share-url="https://www.jobindex.dk/vis-job/h1002649" href="/send-link?link=https%253A%252F%252Fwww.jobindex.dk%252Fvis-job%252Fh1002649&amp;s=25c795af16093be5fa125aa59648313a3d8cc46e">Del</a></li>
# <li class="toolbar-pubdate"><span class="d-none d-md-inline">Indrykket </span><time datetime="2020-08-24">24. august</time></li>
# </ul>
# <ul class="toolbar-line toolbar-line-secondary">
# <li class="toolbar-companyprofile">
# <a href="/virksomhed/27489/copenhagen-fertility-center" onclick="ga('send', 'event', 'jobannonce', 'click', 'om-virksomheden', {transport: 'beacon'})">Om virksomheden</a>
# </li>
# <li class="jobad-element-quickapply">
# <a class="btn btn-sm btn-primary" href="https://www.jobindex.dk/ansoegninger/opret/1308029" onclick='ga("send", "event", "jobannonce", "click", "quick-apply", {transport: "beacon"})'>QuickApply</a>
# </li>
# </ul>
# </div>
# <div style="clear:both;"></div>
# </div>
# </div></div>, <div class="jobsearch-result"><div data-beacon-tid="h1002635"> <div class="PaidJob">
# <center style="margin-bottom: 15px;"><a data-click="/c?t=h1002635&amp;ctx=w&amp;u=15114019" href="http://ds-sundhed.dk/" rel="noopener" target="_blank"><img alt="Dansk Sundhedssikring A/S" src="/img/brand/dansk-sundhedssikring-spo-topp.jpg" style="border: 0px; margin: 0;"/></a></center><a data-click="/c?t=h1002635&amp;ctx=w&amp;u=20348456" href="https://ds-sundhed.career.emply.com/ad/psykolog-og-netvaerkskoordinator-til-primacare/jb2mki/da" rel="noopener" target="_blank"><b>Psykolog og netværkskoordinator til PrimaCare</b></a>
# <p>
# <a data-click="/c?t=h1002635&amp;ctx=w&amp;u=15114019" href="http://ds-sundhed.dk/" rel="noopener" target="_blank"><b>Dansk Sundhedssikring A/S</b></a>, Herlev</p>
# <p><b>Er du autoriseret psykolog og har du lyst til at bruge dine kompetencer alsidigt indenfor både sundhedsfaglige, administrative og udviklingsorienterede opgaver?</b></p>
# <p> PrimaCare håndterer henvendelser fra medarbejdere, der via deres virksomhed (vores kunder) har en Sundhedsforsikring. Via vores netværk af klinikker tilbyder vores behandlere en bred vifte af behandlingsmuligheder med fokus på psykologi, fysioterapi og kiropraktik. </p>
# <p> Du kommer til at referere til Drifts- og netværkschefen i PrimaCare og indgå i vores team bestående af 11 medarbejdere, der er en blanding af psykologer, fysioterapeuter og sundhedsfaglige medarbejdere. </p>
# <p> DINE ARBEJDSOPGAVER</p>
# <ul>
# <li> Dialog på udvalgte psykolog-sager, samt sparring om sagerne med internt og eksternt sundhedspersonale, herunder sygeplejersker og psykologer </li>
# <li> Sagsbehandling/administration ift. psykolog-sager </li>
# </ul><center><a data-click="/c?t=h1002635&amp;ctx=w&amp;u=20049170" href="https://www.jobindex.dk/virksomhed/36309/dansk-sundhedssikring-a-s" rel="noopener" target="_blank"><img alt="Dansk Sundhedssikring A/S" src="/img/brand/dansk-sundhedssikring-spo-bund.jpg" style="border: 0px; margin-top: 5px;"/></a></center>
# <div class="jix_toolbar jix_appetizer_toolbar" id="jix_toolbar_h1002635">
# <ul class="toolbar-line toolbar-line-primary">
# <li class="jobad-element-myjob" data-state="unsaved">
# <a data-action="add-dialog" href="/bruger/dine-job/h1002635/gem" rel="nofollow">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-unsaved" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#         Gem job
# </a></li>
# <li class="jobad-element-myjob-interest" data-state="notallowed">
# <a data-action="handlecontact" href="/bruger/dine-job/h1002635/skift_kontakt" rel="nofollow">
# <span class=""><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-interest-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Vis interesse</span>
# </a></li>
# <li class="jobad-element-share"><a data-share-popup-url="/share/popup/h1002635" data-share-tid="h1002635" data-share-title="Psykolog og netværkskoordinator til PrimaCare" data-share-url="https://www.jobindex.dk/vis-job/h1002635" href="/send-link?link=https%253A%252F%252Fwww.jobindex.dk%252Fvis-job%252Fh1002635&amp;s=022b2dd61b243e04c2e38e134650283e3b3e17ce">Del</a></li>
# <li class="toolbar-pubdate"><span class="d-none d-md-inline">Indrykket </span><time datetime="2020-08-24">24. august</time></li>
# </ul>
# <ul class="toolbar-line toolbar-line-secondary has-rating">
# <li class="toolbar-companyprofile">
# <a href="/virksomhed/36309/dansk-sundhedssikring-a-s" onclick="ga('send', 'event', 'jobannonce', 'click', 'om-virksomheden', {transport: 'beacon'})">Om virksomheden</a>
# <span class="ratings">
# <a class="rating-score" href="/virksomhed/36309/dansk-sundhedssikring-a-s#show_rating" onclick="ga('send', 'event', 'jobannonce', 'click', 'evalueringsstjerner', {transport: 'beacon'})">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# <span class="sr-only">5 af 5 stjerner</span>
# </a>
# <a class="num-ratings" href="/virksomhed/36309/dansk-sundhedssikring-a-s#show_rating" onclick="ga('send', 'event', 'jobannonce', 'click', 'evalueringsstjerner', {transport: 'beacon'})">14</a>
# </span>
# </li>
# <li class="jobad-element-quickapply">
# <a class="btn btn-sm btn-primary" href="https://www.jobindex.dk/c?t=e1270825&amp;ctx=w&amp;u=20348457&amp;f=jobdk" onclick='ga("send", "event", "jobannonce", "click", "quick-apply", {transport: "beacon"})'>QuickApply</a>
# </li>
# </ul>
# </div>
# <div style="clear:both;"></div>
# </div>
# </div></div>, <div class="jobsearch-result"><div data-beacon-tid="h1002623"> <div class="PaidJob">
# <a data-click="/c?t=h1002623&amp;ctx=w&amp;u=15137575" href="http://www.vardekommune.dk/" rel="noopener" target="_blank"><img align="right" alt="Varde Kommune" src="/img/logo/VardeKommune_logo.png" style="border: 0px; margin: 0 0 5px 20px;"/></a><a data-click="/c?t=h1002623&amp;ctx=w&amp;u=20348439" href="https://Varde.emply.net/recruitment/vacancyAd.aspx?publishingId=fce394b0-a687-4d21-87c6-b291377c17cd" rel="noopener" target="_blank"><b>Sygeplejen i Varde Kommune søger en kombineret Souschef /teamleder for akutfunktionen</b></a>
# <p>
# <a data-click="/c?t=h1002623&amp;ctx=w&amp;u=15137575" href="http://www.vardekommune.dk/" rel="noopener" target="_blank"><b>Varde Kommune</b></a></p>
# <p>Vil du være med til at videreudvikle og præge Sygeplejen i Varde Kommune, og har du lyst til at være en del af en værdiskabende og stærk organisation med blik for detaljen - så har du chancen nu! </p>
# <p> Vi leverer sygepleje til kommunens borgere, og i disse år oplever vi en stigende kompleksitet. De opgaver, der overdrages fra sygehusene, kræver i dag et højt basis- og specialiseringsniveau blandt sygeplejerskerne. </p>
# <p> Som teamleder af Akutfunktionen, bliver du leder for en gruppe fagligt dygtige og engagerede sygeplejersker. Teamet består af 6 sygeplejersker, og sammen skal I være med til at sikre, at Sygeplejen kan håndtere den stigende kompleksitet, samt at vi forbliver det faglige fyrtårn. En af dine første arbejdsopgaver bliver at lave en strategiplan for akutfunktionen.</p>
# <div class="jix_toolbar jix_appetizer_toolbar" id="jix_toolbar_h1002623">
# <ul class="toolbar-line toolbar-line-primary">
# <li class="jobad-element-myjob" data-state="unsaved">
# <a data-action="add-dialog" href="/bruger/dine-job/h1002623/gem" rel="nofollow">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-unsaved" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#         Gem job
# </a></li>
# <li class="jobad-element-myjob-interest" data-state="notallowed">
# <a data-action="handlecontact" href="/bruger/dine-job/h1002623/skift_kontakt" rel="nofollow">
# <span class=""><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-interest-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Vis interesse</span>
# </a></li>
# <li class="jobad-element-share"><a data-share-popup-url="/share/popup/h1002623" data-share-tid="h1002623" data-share-title="Sygeplejen i Varde Kommune søger en kombineret Souschef /teamleder for akutfunktionen" data-share-url="https://www.jobindex.dk/vis-job/h1002623" href="/send-link?link=https%253A%252F%252Fwww.jobindex.dk%252Fvis-job%252Fh1002623&amp;s=99d3675dceff4da4e9aa09c95aa250645a3a107f">Del</a></li>
# <li class="toolbar-pubdate"><span class="d-none d-md-inline">Indrykket </span><time datetime="2020-08-24">24. august</time></li>
# </ul>
# <ul class="toolbar-line toolbar-line-secondary has-rating">
# <li class="toolbar-companyprofile">
# <a href="/virksomhed/28207/varde-kommune" onclick="ga('send', 'event', 'jobannonce', 'click', 'om-virksomheden', {transport: 'beacon'})">Om virksomheden</a>
# <span class="ratings">
# <a class="rating-score" href="/virksomhed/28207/varde-kommune#show_rating" onclick="ga('send', 'event', 'jobannonce', 'click', 'evalueringsstjerner', {transport: 'beacon'})">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# <span class="sr-only">4 af 5 stjerner</span>
# </a>
# <a class="num-ratings" href="/virksomhed/28207/varde-kommune#show_rating" onclick="ga('send', 'event', 'jobannonce', 'click', 'evalueringsstjerner', {transport: 'beacon'})">46</a>
# </span>
# </li>
# <li class="jobad-element-quickapply">
# <a class="btn btn-sm btn-primary" href="https://www.jobindex.dk/c?t=e1270822&amp;ctx=w&amp;u=20348440&amp;f=jobdk" onclick='ga("send", "event", "jobannonce", "click", "quick-apply", {transport: "beacon"})'>QuickApply</a>
# </li>
# </ul>
# </div>
# <div style="clear:both;"></div>
# </div>
# </div></div>, <div class="jobsearch-result"><div data-beacon-tid="h1002610"> <div class="PaidJob">
# <a data-click="/c?t=h1002610&amp;ctx=w&amp;u=13590716" href="http://www.tier1asset.com/" rel="noopener" target="_blank"><img align="right" alt="Tier1 Asset A/S" src="/img/logo/tierasset_logo.gif" style="border: 0px; margin: 0 0 5px 20px;"/></a><a data-click="/c?t=h1002610&amp;ctx=w&amp;u=20348516" href="https://www.jobindex.dk/jobannonce/366125/hr-manager" rel="noopener" target="_blank"><b>HR Manager</b></a>
# <p>
# <a data-click="/c?t=h1002610&amp;ctx=w&amp;u=13590716" href="http://www.tier1asset.com/" rel="noopener" target="_blank"><b>Tier1 Asset A/S</b></a>, Allerød</p>
# <p> At T1A, we are on a constant journey, driven by curiosity. Our curiosity has enabled us to challenge what has been known so far within our industry. </p>
# <p> Are you a skilled and experienced HR profile with management experience? Do you want to head HR in a medium-sized circular Danish export company that values the environment and quality? </p>
# <p> We can offer a central role where your efforts are important for the success of the company: </p>
# <ul>
# <li>Skilled and committed colleagues and employees and a workplace with good development opportunities </li>
# <li>Opportunity to participate in canteen arrangements </li>
# <li>Salary according to qualifications and health insurance </li>
# </ul>
# <div class="jix_toolbar jix_appetizer_toolbar" id="jix_toolbar_h1002610">
# <ul class="toolbar-line toolbar-line-primary">
# <li class="jobad-element-myjob" data-state="unsaved">
# <a data-action="add-dialog" href="/bruger/dine-job/h1002610/gem" rel="nofollow">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-unsaved" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#         Gem job
# </a></li>
# <li class="jobad-element-myjob-interest" data-state="notallowed">
# <a data-action="handlecontact" href="/bruger/dine-job/h1002610/skift_kontakt" rel="nofollow">
# <span class=""><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-interest-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Vis interesse</span>
# </a></li>
# <li class="jobad-element-share"><a data-share-popup-url="/share/popup/h1002610" data-share-tid="h1002610" data-share-title="HR Manager" data-share-url="https://www.jobindex.dk/vis-job/h1002610" href="/send-link?link=https%253A%252F%252Fwww.jobindex.dk%252Fvis-job%252Fh1002610&amp;s=a5786390c1932e97bedbbcc8df92a659f99f0ac2">Del</a></li>
# <li class="toolbar-pubdate"><span class="d-none d-md-inline">Indrykket </span><time datetime="2020-08-24">24. august</time></li>
# </ul>
# <ul class="toolbar-line toolbar-line-secondary has-rating">
# <li class="toolbar-companyprofile">
# <a href="/virksomhed/29394/tier1-asset-a-s" onclick="ga('send', 'event', 'jobannonce', 'click', 'om-virksomheden', {transport: 'beacon'})">Om virksomheden</a>
# <span class="ratings">
# <a class="rating-score" href="/virksomhed/29394/tier1-asset-a-s#show_rating" onclick="ga('send', 'event', 'jobannonce', 'click', 'evalueringsstjerner', {transport: 'beacon'})">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# <span class="sr-only">4 af 5 stjerner</span>
# </a>
# <a class="num-ratings" href="/virksomhed/29394/tier1-asset-a-s#show_rating" onclick="ga('send', 'event', 'jobannonce', 'click', 'evalueringsstjerner', {transport: 'beacon'})">6</a>
# </span>
# </li>
# <li class="jobad-element-quickapply">
# <a class="btn btn-sm btn-primary" href="https://www.jobindex.dk/ansoegninger/opret/1307975" onclick='ga("send", "event", "jobannonce", "click", "quick-apply", {transport: "beacon"})'>QuickApply</a>
# </li>
# </ul>
# </div>
# <div style="clear:both;"></div>
# </div>
# </div></div>, <div class="jobsearch-result"><div data-beacon-tid="h1002600"> <div class="PaidJob">
# <center style="margin-bottom: 15px;"><a data-click="/c?t=h1002600&amp;ctx=w&amp;u=19585335" href="https://fgu-ns.dk/" rel="noopener" target="_blank"><img alt="FGU Nordsjælland" src="/img/brand/top-produktionsskolen-nordsjaellands-uddannelsescenter.png" style="border: 0px; margin: 0;"/></a></center><a data-click="/c?t=h1002600&amp;ctx=w&amp;u=20348315" href="https://www.jobindex.dk/jobannonce/366114/matematiklaerer-til-agu-undervisning-deltid-65-75-til-hilleroed-afdelingen" rel="noopener" target="_blank"><b>Matematiklærer til AGU-undervisning – deltid (65-75%) til Hillerød-afdelingen</b></a>
# <p>
# <a data-click="/c?t=h1002600&amp;ctx=w&amp;u=19585335" href="https://fgu-ns.dk/" rel="noopener" target="_blank"><b>FGU Nordsjælland</b></a></p>
# ...
# </li>
# </ul>
# </div>
# <div style="clear:both;"></div>
# </div>
# </div></div>, <div class="jobsearch-result"><div data-beacon-tid="h1002581"> <div class="PaidJob">
# <a data-click="/c?t=h1002581&amp;ctx=w&amp;u=15122936" href="http://www.heldagsskolen-lindersvold.dk/" rel="noopener" target="_blank"><img align="right" alt="Heldagsskolen Lindersvold" src="/img/logo/Heldagsskolen210820_logo.png" style="border: 0px; margin: 0 0 5px 20px;"/></a><a data-click="/c?t=h1002581&amp;ctx=w&amp;u=20348507" href="https://www.jobindex.dk/jobannonce/366109/psykolog" rel="noopener" target="_blank"><b>Psykolog</b></a>
# <p>
# <a data-click="/c?t=h1002581&amp;ctx=w&amp;u=15122936" href="http://www.heldagsskolen-lindersvold.dk/" rel="noopener" target="_blank"><b>Heldagsskolen Lindersvold</b></a>, Faxe</p>
# <p> Vi søger en uddannet psykolog til ¼ stilling til Heldagsskolen Lindersvold. </p>
# <p> Heldagsskolen Lindersvold er et dagbehandlingstilbud for elever med særlige behov. Hovedparten af elevgruppen består af børn og unge med forskellige diagnoser. Vi har elever med diagnoser inden for autismespekteret med tilhørende med tilhørende komorbiditet. </p>
# <p>Arbejdsopgaverne vil bestå af følgende: </p>
# <ul>
# <li>Stå for rådgivning og vejledning til personalet.<br/>
# Deltage i visse personalemøder.</li>
# <li>Deltage i indskrivningsmøder af nye elever. Herunder udarbejdelse af behandlingsplaner.</li>
# <li>Deltage i statusmøder med sagsbehandlere, PPR og forældre, opholdssteder, plejefamilier.</li>
# <li>Stå for dokumentationsarbejdet til kommunerne og sørge for at tilsynet har et højt niveau.</li>
# </ul>
# <div class="jix_toolbar jix_appetizer_toolbar" id="jix_toolbar_h1002581">
# <ul class="toolbar-line toolbar-line-primary">
# <li class="jobad-element-myjob" data-state="unsaved">
# <a data-action="add-dialog" href="/bruger/dine-job/h1002581/gem" rel="nofollow">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-unsaved" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#         Gem job
# </a></li>
# <li class="jobad-element-myjob-interest" data-state="notallowed">
# <a data-action="handlecontact" href="/bruger/dine-job/h1002581/skift_kontakt" rel="nofollow">
# <span class=""><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-interest-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Vis interesse</span>
# </a></li>
# <li class="jobad-element-share"><a data-share-popup-url="/share/popup/h1002581" data-share-tid="h1002581" data-share-title="Psykolog" data-share-url="https://www.jobindex.dk/vis-job/h1002581" href="/send-link?link=https%253A%252F%252Fwww.jobindex.dk%252Fvis-job%252Fh1002581&amp;s=76dabaf364c13769b900de230ae138cd907449c4">Del</a></li>
# <li class="toolbar-pubdate"><span class="d-none d-md-inline">Indrykket </span><time datetime="2020-08-24">24. august</time></li>
# </ul>
# <ul class="toolbar-line toolbar-line-secondary">
# <li class="toolbar-companyprofile">
# <a href="/virksomhed/43011/heldagsskolen-lindersvold" onclick="ga('send', 'event', 'jobannonce', 'click', 'om-virksomheden', {transport: 'beacon'})">Om virksomheden</a>
# </li>
# <li class="jobad-element-quickapply">
# <a class="btn btn-sm btn-primary" href="https://www.jobindex.dk/ansoegninger/opret/1307923" onclick='ga("send", "event", "jobannonce", "click", "quick-apply", {transport: "beacon"})'>QuickApply</a>
# </li>
# </ul>
# </div>
# <div style="clear:both;"></div>
# </div>
# </div></div>, <div class="jobsearch-result"><div data-beacon-tid="h1002580"> <div class="PaidJob">
# <a data-click="/c?t=h1002580&amp;ctx=w&amp;u=20313713" href="https://www.autobasen.dk/" rel="noopener" target="_blank"><img align="right" alt="Autobasen ApS" src="/img/logo/Autobasen_logo20.png" style="border: 0px; margin: 0 0 5px 20px;"/></a><a data-click="/c?t=h1002580&amp;ctx=w&amp;u=20348287" href="https://www.jobindex.dk/jobannonce/366108/administrationsmedarbejder" rel="noopener" target="_blank"><b>Administrationsmedarbejder</b></a>
# <p>
# <a data-click="/c?t=h1002580&amp;ctx=w&amp;u=20313713" href="https://www.autobasen.dk/" rel="noopener" target="_blank"><b>Autobasen ApS</b></a>, Aarhus</p>
# <p> Vi søger ny polsktalende administrationsmedarbejder (m/k) med dansk- og engelsksproglige kompetencer, og tysk vil være et plus. </p>
# <p> Autobasen i Aarhus, nord for Aarhus, er specialiseret i opkøb og eksport af biler fra privatmarkedet i Danmark til eksport mod Polen, Rumænien, Tyskland og andre EU-lande. </p>
# <p> Du vil indgå i et dynamisk team bestående af ni medarbejdere. Du vil sammen med vores driftschef stå i spidsen for afhentning af dokumentationsbilag i forbindelse med salg, samt håndtering/arkivering af disse. Derforuden vil du også have kontakt med den enkelte kunde, når vedkommende besøger Autobasen for at afhente/indkøbe en eller flere af vores hundredvis af eksportbiler. </p>
# <div class="jix_toolbar jix_appetizer_toolbar" id="jix_toolbar_h1002580">
# <ul class="toolbar-line toolbar-line-primary">
# <li class="jobad-element-myjob" data-state="unsaved">
# <a data-action="add-dialog" href="/bruger/dine-job/h1002580/gem" rel="nofollow">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-unsaved" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#         Gem job
# </a></li>
# <li class="jobad-element-myjob-interest" data-state="notallowed">
# <a data-action="handlecontact" href="/bruger/dine-job/h1002580/skift_kontakt" rel="nofollow">
# <span class=""><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-interest-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Vis interesse</span>
# </a></li>
# <li class="jobad-element-share"><a data-share-popup-url="/share/popup/h1002580" data-share-tid="h1002580" data-share-title="Administrationsmedarbejder" data-share-url="https://www.jobindex.dk/vis-job/h1002580" href="/send-link?link=https%253A%252F%252Fwww.jobindex.dk%252Fvis-job%252Fh1002580&amp;s=de80ce65ff275723d5945cec877b8f13b1c4d88d">Del</a></li>
# <li class="toolbar-pubdate"><span class="d-none d-md-inline">Indrykket </span><time datetime="2020-08-24">24. august</time></li>
# </ul>
# <ul class="toolbar-line toolbar-line-secondary">
# <li class="toolbar-companyprofile">
# <a href="/virksomhed/56604/autobasen-aps" onclick="ga('send', 'event', 'jobannonce', 'click', 'om-virksomheden', {transport: 'beacon'})">Om virksomheden</a>
# </li>
# <li class="jobad-element-quickapply">
# <a class="btn btn-sm btn-primary" href="https://www.jobindex.dk/ansoegninger/opret/1307921" onclick='ga("send", "event", "jobannonce", "click", "quick-apply", {transport: "beacon"})'>QuickApply</a>
# </li>
# </ul>
# </div>
# <div style="clear:both;"></div>
# </div>
# </div></div>, <div class="jobsearch-result"><div data-beacon-tid="h1002575"> <div class="PaidJob">
# <a data-click="/c?t=h1002575&amp;ctx=w&amp;u=15121066" href="http://www.startex.dk/" rel="noopener" target="_blank"><img align="right" alt="STARTEX ApS" src="/img/logo/Startex_logo_mer20150324.gif" style="border: 0px; margin: 0 0 5px 20px;"/></a><a data-click="/c?t=h1002575&amp;ctx=w&amp;u=20348279" href="https://www.jobindex.dk/jobannonce/366106/startex-soeger-salgstalenter-med-drive-og-ambitioner-til-meget-mere" rel="noopener" target="_blank"><b>STARTEX søger salgstalenter - med drive og ambitioner til meget mere</b></a>
# <p>
# <a data-click="/c?t=h1002575&amp;ctx=w&amp;u=15121066" href="http://www.startex.dk/" rel="noopener" target="_blank"><b>STARTEX ApS</b></a>, Svenstrup</p>
# <p> STARTEX er i en sund og stærk udvikling og vækster på de europæiske markeder. For at sikre den fortsatte positive udvikling i vores salgsafdelinger søger vi nu 2 energiske og entusiastiske salgstalenter, der har mod på en travl og hektisk hverdag med vores kunder, som er nogle af Europas største detailkæder. Du kan blive en del af et ungt og dynamisk salgsteam, hvor dit drive og dine indsatser hurtigt vil give resultater. </p>
# <p>Vi tilbyder </p>
# <ul>
# <li>Ansvar og opgaver, der afspejler dit niveau, samt dine ønsker og drømme indenfor salg og relationsopbygning</li>
# <li>En konkret og målrettet udviklings- og karriereplan, der tager udgangspunkt i dig og dine udviklingsmuligheder</li>
# <li>En spændende virksomhedskultur, der bygger på stærke værdier som vindermentalitet, begejstring og ordentlighed</li>
# </ul>
# <div class="jix_toolbar jix_appetizer_toolbar" id="jix_toolbar_h1002575">
# <ul class="toolbar-line toolbar-line-primary">
# <li class="jobad-element-myjob" data-state="unsaved">
# <a data-action="add-dialog" href="/bruger/dine-job/h1002575/gem" rel="nofollow">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-unsaved" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#         Gem job
# </a></li>
# <li class="jobad-element-myjob-interest" data-state="notallowed">
# <a data-action="handlecontact" href="/bruger/dine-job/h1002575/skift_kontakt" rel="nofollow">
# <span class=""><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-interest-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Vis interesse</span>
# </a></li>
# <li class="jobad-element-share"><a data-share-popup-url="/share/popup/h1002575" data-share-tid="h1002575" data-share-title="STARTEX søger salgstalenter - med drive og ambitioner til meget mere" data-share-url="https://www.jobindex.dk/vis-job/h1002575" href="/send-link?link=https%253A%252F%252Fwww.jobindex.dk%252Fvis-job%252Fh1002575&amp;s=66471e7e77e8693cd0051d9d3f0c0a3bfa8626b6">Del</a></li>
# <li class="toolbar-pubdate"><span class="d-none d-md-inline">Indrykket </span><time datetime="2020-08-24">24. august</time></li>
# </ul>
# <ul class="toolbar-line toolbar-line-secondary has-rating">
# <li class="toolbar-companyprofile">
# <a href="/virksomhed/24011/startex-aps" onclick="ga('send', 'event', 'jobannonce', 'click', 'om-virksomheden', {transport: 'beacon'})">Om virksomheden</a>
# <span class="ratings">
# <a class="rating-score" href="/virksomhed/24011/startex-aps#show_rating" onclick="ga('send', 'event', 'jobannonce', 'click', 'evalueringsstjerner', {transport: 'beacon'})">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# <span class="sr-only">4 af 5 stjerner</span>
# </a>
# <a class="num-ratings" href="/virksomhed/24011/startex-aps#show_rating" onclick="ga('send', 'event', 'jobannonce', 'click', 'evalueringsstjerner', {transport: 'beacon'})">4</a>
# </span>
# </li>
# <li class="jobad-element-quickapply">
# <a class="btn btn-sm btn-primary" href="https://www.jobindex.dk/ansoegninger/opret/1307913" onclick='ga("send", "event", "jobannonce", "click", "quick-apply", {transport: "beacon"})'>QuickApply</a>
# </li>
# </ul>
# </div>
# <div style="clear:both;"></div>
# </div>
# </div></div>, <div class="jobsearch-result"><div data-beacon-tid="h1002558"> <div class="PaidJob">
# <a data-click="/c?t=h1002558&amp;ctx=w&amp;u=14161170" href="http://www.agrometer.dk/" rel="noopener" target="_blank"><img align="right" alt="Agrometer A/S" src="/img/logo/AGM_logo.png" style="border: 0px; margin: 0 0 5px 20px;"/></a><a data-click="/c?t=h1002558&amp;ctx=w&amp;u=20348263" href="https://www.jobindex.dk/jobannonce/366099/servicemontoer-sjaelland-og-oeer-sportsvandingsanlaeg" rel="noopener" target="_blank"><b>SERVICEMONTØR – SJÆLLAND OG ØER – sportsvandingsanlæg</b></a>
# <p>
# <a data-click="/c?t=h1002558&amp;ctx=w&amp;u=14161170" href="http://www.agrometer.dk/" rel="noopener" target="_blank"><b>Agrometer A/S</b></a></p>
# <p><i> Har du erfaring med fejlfinding og service af tekniske installationer – og sætter du en ære i at levere gode, holdbare løsninger til glæde for din kunde? Formår du at arbejde struktureret i en hverdag, der til tider er hektisk? Ser dine omgivelser dig som service-minded? Så er du måske vores nye Servicemontør. </i></p>
# <p> Primære opgaver: </p>
# <ul>
# <li>Etablering og installation af nye pop-up vandingsanlæg </li>
# <li>Service, fejlfinding og reparation af vandingsanlæg hos eksisterende og nye kunder </li>
# <li>Dataindsamling i forbindelse med nye projekter </li>
# </ul>
# <p> Du bliver del af et stærkt og kompetent team, der har arbejdet sig til en markedsledende position på området for vandingsanlæg. Vi har en flad og uformel organisation i virksomheden, og hjælper hinanden med at nå vores fælles mål.</p>
# <div class="jix_toolbar jix_appetizer_toolbar" id="jix_toolbar_h1002558">
# <ul class="toolbar-line toolbar-line-primary">
# <li class="jobad-element-myjob" data-state="unsaved">
# <a data-action="add-dialog" href="/bruger/dine-job/h1002558/gem" rel="nofollow">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-unsaved" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#         Gem job
# </a></li>
# <li class="jobad-element-myjob-interest" data-state="notallowed">
# <a data-action="handlecontact" href="/bruger/dine-job/h1002558/skift_kontakt" rel="nofollow">
# <span class=""><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-myjob-interest-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Vis interesse</span>
# </a></li>
# <li class="jobad-element-share"><a data-share-popup-url="/share/popup/h1002558" data-share-tid="h1002558" data-share-title="SERVICEMONTØR – SJÆLLAND OG ØER – sportsvandingsanlæg" data-share-url="https://www.jobindex.dk/vis-job/h1002558" href="/send-link?link=https%253A%252F%252Fwww.jobindex.dk%252Fvis-job%252Fh1002558&amp;s=b5ffe3a22d14604dbcb33fea0dbdaaef45dc69d7">Del</a></li>
# <li class="toolbar-pubdate"><span class="d-none d-md-inline">Indrykket </span><time datetime="2020-08-24">24. august</time></li>
# </ul>
# <ul class="toolbar-line toolbar-line-secondary has-rating">
# <li class="toolbar-companyprofile">
# <a href="/virksomhed/26156/agrometer-a-s" onclick="ga('send', 'event', 'jobannonce', 'click', 'om-virksomheden', {transport: 'beacon'})">Om virksomheden</a>
# <span class="ratings">
# <a class="rating-score" href="/virksomhed/26156/agrometer-a-s#show_rating" onclick="ga('send', 'event', 'jobannonce', 'click', 'evalueringsstjerner', {transport: 'beacon'})">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-selected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-rating-unselected" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# <span class="sr-only">3 af 5 stjerner</span>
# </a>
# <a class="num-ratings" href="/virksomhed/26156/agrometer-a-s#show_rating" onclick="ga('send', 'event', 'jobannonce', 'click', 'evalueringsstjerner', {transport: 'beacon'})">3</a>
# </span>
# </li>
# <li class="jobad-element-quickapply">
# <a class="btn btn-sm btn-primary" href="https://www.jobindex.dk/ansoegninger/opret/1307889" onclick='ga("send", "event", "jobannonce", "click", "quick-apply", {transport: "beacon"})'>QuickApply</a>
# </li>
# </ul>
# </div>
# <div style="clear:both;"></div>
# </div>
# </div></div>]
# [['2020-08-24'], ['2020-08-24'], ['2020-08-24'], ['2020-08-24'], ['2020-08-24'], ['2020-08-24'], ['2020-08-24'], ['2020-08-24'], ['2020-08-24'], ['2020-08-24'], ['2020-08-24'], ['2020-08-24'], ['2020-08-24'], ['2020-08-24'], ['2020-08-24'], ['2020-08-24'], ['2020-08-24'], ['2020-08-24'], ['2020-08-24'], ['2020-08-24']]
